# %%
print("hello")
# Out:
# hello

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    model="llama-3.1-8b-instant",
    model_provider="groq"
)
model
# Out:
# d:\dev\langchain-1\.venv\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000026520A3E410>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000026520B9E910>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
response = model.invoke(
    "write an essay on the topic dogs are friendly to humans"
)
print(response.content)
# Out:
# **The Unwavering Bond: Why Dogs are Friendly to Humans**
#
# Dogs have been humanity's most loyal and trusted companions for thousands of years. Their unwavering love and affection towards humans have made them an integral part of our lives. From ancient civilizations to modern times, dogs have consistently demonstrated their friendly nature, earning them the title of "man's best friend." In this essay, we will explore the reasons behind a dog's friendly demeanor and the benefits that come with having a dog as a companion.
#
# One of the primary reasons dogs are friendly to humans is their evolution as pack animals. In the wild, dogs were social creatures that lived in packs, relying on each other for survival and protection. This pack mentality has been passed down through generations, making dogs natural socializers. They have adapted to live alongside humans, recognizing them as part of their pack and therefore deserving of loyalty and affection. This instinctual behavior is evident in the way dogs greet their owners, often with excitement and enthusiasm, as if reuniting with a long-lost pack member.
#
# Another factor contributing to a dog's friendly nature is their ability to read human emotions. Dogs possess a unique capacity to pick up on subtle cues, such as body language and tone of voice, allowing them to empathize with humans on a deep level. This emotional intelligence enables them to respond to our needs and comfort us when we are feeling down. A simple nuzzle or lick on the hand can be enough to brighten someone's day, highlighting the profound impact dogs have on our emotional well-being.
#
# Dogs are also quick to form close bonds with their human family members, often becoming an integral part of the household. This attachment stems from their need for attention and affection, which they receive in abundance from their owners. As a result, dogs become fiercely loyal and protective of their family, often going to great lengths to defend and care for them. This loyalty is a testament to the strong bond that exists between dogs and humans, one that is built on trust, love, and mutual respect.
#
# In addition to their emotional benefits, dogs also provide numerous physical advantages to humans. They can encourage us to lead healthier lifestyles by promoting exercise and outdoor activities, such as walking and running. This physical activity can lead to improved cardiovascular health, weight management, and a reduced risk of chronic diseases. Furthermore, studies have shown that dog owners tend to have lower blood pressure, cholesterol levels, and body mass index compared to non-dog owners.
#
# In conclusion, dogs are friendly to humans due to their evolution as pack animals, their ability to read human emotions, their capacity to form close bonds, and their physical benefits. Their unwavering love and loyalty have made them an essential part of our lives, providing us with companionship, comfort, and support. As we continue to share our lives with dogs, we can appreciate the profound impact they have on our emotional and physical well-being, solidifying their place as "man's best friend" for generations to come.
#
# **References**
#
# * Bradshaw, J. (2009). Dog Sense: How the New Science of Dog Behavior Can Make You a Better Friend to Your Pet. Basic Books.
# * Odendaal, J. S. (2003). The Therapeutic Benefits of Animal-Assisted Therapy. Journal of Clinical Psychology, 59(2), 179-188.
# * Serpell, J. (1995). The Domestic Dog: Its Evolution, Behaviour and Interactions with People. Cambridge University Press.
#
# **Note:** The citations provided are a selection of examples and are not exhaustive. They are intended to support the arguments presented in the essay and provide additional information for readers interested in the topic.

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.1-8b-instant")

# %%
response=model.invoke("what is the full form of gpu?")

# %%
response.content
# Out:
# 'The full form of GPU is Graphics Processing Unit.'
