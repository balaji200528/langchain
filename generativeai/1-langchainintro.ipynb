# %%
print('hello')
# Out:
# hello

# %%
import langchain
print(langchain.___version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import langchain
# ----> 2 print(langchain.___version__)
#
# AttributeError: module 'langchain' has no attribute '___version__'

# %%
from importlib.metadata import version
print(version("langchain"))
# Out:
# 1.2.7

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Generative AI Application using groq model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    model="llama-3.1-70b-versatile",
    model_provider="groq"
)
model
# Out:
# ChatGroq(profile={}, client=<groq.resources.chat.completions.Completions object at 0x000001CB2F27A610>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001CB2F27EAD0>, model_name='llama-3.1-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))
